# %%
import pandas as pd

# %%
file_path = "../1.DATASET/CMI_FINAL_OD.csv"
df=pd.read_csv(file_path)

# %%
df.describe([.01,.1,.2,.3,.4,.5,.6,.7,.8,.9,.95])
# Out:
#                 id  Basic_Demos-Age  Basic_Demos-Sex  Physical-BMI  \
# count  8396.000000      8396.000000      8396.000000   8396.000000
# mean   4233.378037        10.209147         0.403168     19.311053
# std    2443.288170         3.550147         0.490563      4.328157
# min       0.000000         5.000000         0.000000      8.522436
# 1%       83.950000         5.000000         0.000000     13.730469
# 10%     846.500000         6.000000         0.000000     15.424007
# 20%    1693.000000         7.000000         0.000000     16.141329
# 30%    2542.500000         8.000000         0.000000     16.836794
# 40%    3392.000000         9.000000         0.000000     17.400000
# 50%    4234.500000        10.000000         0.000000     17.937682
# 60%    5080.000000        10.000000         1.000000     18.742090
# 70%    5926.500000        12.000000         1.000000     20.094411
# 80%    6771.000000        13.000000         1.000000     22.362821
# ...

# %%
#df.describe([.01,.1,.2,.3,.4,.5,.6,.7,.8,.9,.98])
df[df["BIA-BIA_DEE"]>4000]
# Out:
#         id  Basic_Demos-Age  Basic_Demos-Sex  Physical-BMI  Physical-Height  \
# 1413  1423               20                0     23.211846        69.000000
# 1688  1702               15                0     20.754316        66.000000
# 2183  2202               14                0     23.041184        70.000000
# 2278  2299               13                1     24.825467        65.000000
# 2388  2410               20                0     31.628724        71.000000
# 2455  2478               17                0     21.100849        72.000000
# 2467  2490               18                0     27.255221        67.300000
# 2742  2770                9                0     16.947321        56.000000
# 3061  3091               14                0     18.330074        67.500000
# 3116  3147                8                0     16.110417        48.000000
# 3476  3511               13                1     23.605261        61.500000
# ...

# %%
df = df[df["BIA-BIA_DEE"]<=4000]

# %%
df.to_csv('../1.DATASET/CMI_FINAL_OD_1.csv', index=False)
